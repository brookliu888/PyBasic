# %% [markdown]
# <a href="https://colab.research.google.com/github/brookliu888/PyBasic/blob/main/ListDic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get Data from KH API

# %%
import requests

# %%
rul = "https://api.kcg.gov.tw/api/service/get/897e552a-2887-4f6f-a6ee-709f7fbe0ee3"

# %%
data = requests.get(rul).json()

# %%
print(data)
# Out:
# {'isImage': False, 'data': [{'seq': 1, '行政區': '大社區', '臨時停車處所': '老人文康活動中心', '可提供小型車停車位': '10', '地址': '金龍路65號'}, {'seq': 2, '行政區': '岡山區', '臨時停車處所': '岡山國中', '可提供小型車停車位': '84', '地址': '岡燕路238號'}, {'seq': 3, '行政區': '岡山區', '臨時停車處所': '嘉興國中', '可提供小型車停車位': '16', '地址': '嘉興里信中街486號'}, {'seq': 4, '行政區': '岡山區', '臨時停車處所': '前峰國中', '可提供小型車停車位': '50', '地址': '樹人路1號'}, {'seq': 5, '行政區': '岡山區', '臨時停車處所': '岡山國小', '可提供小型車停車位': '20', '地址': '柳橋東路36號'}, {'seq': 6, '行政區': '岡山區', '臨時停車處所': '前峰國小', '可提供小型車停車位': '50', '地址': '育英路35號'}, {'seq': 7, '行政區': '岡山區', '臨時停車處所': '後紅國小', '可提供小型車停車位': '30', '地址': '岡燕路2巷88號'}, {'seq': 8, '行政區': '岡山區', '臨時停車處所': '竹圍國小', '可提供小型車停車位': '30', '地址': '大仁北路1號'}, {'seq': 9, '行政區': '岡山區', '臨時停車處所': '壽天國小', '可提供小型車停車位': '40', '地址': '公園東路55號'}, {'seq': 10, '行政區': '路竹區', '臨時停車處所': '蔡文國小', '可提供小型車停車位': '60', '地址': '國昌路548號'}, {'seq': 11, '行政區': '路竹區', '臨時停車處所': '一甲國中', '可提供小型車停車位': '50', '地址': '一甲路 111 號'}, {'seq': 12, '行政區': '路竹區', '臨時停車處所': '路竹高中', '可提供小型車停車位': '30', '地址': '中華路292號'}, {'
# ...

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['isImage', 'data', 'id', 'success'])

# %%
type(data['data'])
# Out:
# list

# %%
print(data['data'])
# Out:
# [{'seq': 1, '行政區': '大社區', '臨時停車處所': '老人文康活動中心', '可提供小型車停車位': '10', '地址': '金龍路65號'}, {'seq': 2, '行政區': '岡山區', '臨時停車處所': '岡山國中', '可提供小型車停車位': '84', '地址': '岡燕路238號'}, {'seq': 3, '行政區': '岡山區', '臨時停車處所': '嘉興國中', '可提供小型車停車位': '16', '地址': '嘉興里信中街486號'}, {'seq': 4, '行政區': '岡山區', '臨時停車處所': '前峰國中', '可提供小型車停車位': '50', '地址': '樹人路1號'}, {'seq': 5, '行政區': '岡山區', '臨時停車處所': '岡山國小', '可提供小型車停車位': '20', '地址': '柳橋東路36號'}, {'seq': 6, '行政區': '岡山區', '臨時停車處所': '前峰國小', '可提供小型車停車位': '50', '地址': '育英路35號'}, {'seq': 7, '行政區': '岡山區', '臨時停車處所': '後紅國小', '可提供小型車停車位': '30', '地址': '岡燕路2巷88號'}, {'seq': 8, '行政區': '岡山區', '臨時停車處所': '竹圍國小', '可提供小型車停車位': '30', '地址': '大仁北路1號'}, {'seq': 9, '行政區': '岡山區', '臨時停車處所': '壽天國小', '可提供小型車停車位': '40', '地址': '公園東路55號'}, {'seq': 10, '行政區': '路竹區', '臨時停車處所': '蔡文國小', '可提供小型車停車位': '60', '地址': '國昌路548號'}, {'seq': 11, '行政區': '路竹區', '臨時停車處所': '一甲國中', '可提供小型車停車位': '50', '地址': '一甲路 111 號'}, {'seq': 12, '行政區': '路竹區', '臨時停車處所': '路竹高中', '可提供小型車停車位': '30', '地址': '中華路292號'}, {'seq': 13, '行政區': '路竹區', '臨時
# ...

# %%
for i in data['data']:
  print(i['seq'],"=>",i['地址'])
# Out:
# 1 => 金龍路65號
# 2 => 岡燕路238號
# 3 => 嘉興里信中街486號
# 4 => 樹人路1號
# 5 => 柳橋東路36號
# 6 => 育英路35號
# 7 => 岡燕路2巷88號
# 8 => 大仁北路1號
# 9 => 公園東路55號
# 10 => 國昌路548號
# 11 => 一甲路 111 號
# 12 => 中華路292號
# 13 => 中山路712巷16號
# 14 => 大社路243號
# 15 => 竹滬里成功路2號
# 16 => 民治路85號
# 17 => 大智路43號
# 18 => 中正路213號
# 19 => 濱海路四段29號
# 20 => 民治路2號
# 21 => 茄萣路二段307號
# 22 => 成功路1號
# 23 => 萬福里文化路81號
# 24 => 民權路2號
# 25 => 保生路103號
# 26 => 南安里崗安路48號
# 27 => 南安里崗安路71-1號
# 28 => 南安里崗安路71號
# 29 => 崇德路101號
# 30 => 大新路2號
# 31 => 復安里167號
# 32 => 中路里272號
# 33 => 民族路163號
# 34 => 民生路94號
# 35 => 內豐里內埔24號
# 36 => 內東里柿子園24號
# 37 => 溝枰里廣福47號
# 38 => 永富里萊坑8號
# 39 => 觀亭里中正路203號
# 40 => 中正路160巷30號
# 41 => 金竹里吉民28號
# 42 => 木柵里6鄰木柵3號
# 43 => 內門里內門20號
# 44 => 觀亭里南屏路92號
# 45 => 中興路267號
# 46 => 東燕里中華路177號
# 47 => 橫山路24號
# 48 => 瓊林里安招路170號
# 49 => 金山里番田路29號
# 50 => 深水里深中路2號
# 51 => 中安路1號
# 52 => 中興路427號
# 53 => 中華路68號
# 54 => 龍山里龍山街62號
# 55 => 忠孝路二段59號
# 56 => 中正路一段191號(體育館前空地)
# 57 => 興隆里廣興街124號
# 58 => 南中街3號
# 59 => 龍肚里龍東街43號
# 60 => 福安里中山路2段358號
# ...

# %% [markdown]
# #對Json文字剖析

# %%
s = """{
     "firstName": "John",
     "lastName": "Smith",
     "sex": "male",
     "age": 25,
     "address": 
     {
         "streetAddress": "21 2nd Street",
         "city": "New York",
         "state": "NY",
         "postalCode": "10021"
     },
     "phoneNumber": 
     [
         {
           "type": "home",
           "number": "212 555-1234"
         },
         {
           "type": "fax",
           "number": "646 555-4567"
         }
     ]
 } """

# %%
import json

# %%
data = json.loads(s)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['firstName', 'lastName', 'sex', 'age', 'address', 'phoneNumber'])

# %%
c
# Out:
# [{'number': '212 555-1234', 'type': 'home'},
#  {'number': '646 555-4567', 'type': 'fax'}]

# %%
type(data['phoneNumber'])
# Out:
# list

# %%
 data['phoneNumber'][0]
# Out:
# {'number': '212 555-1234', 'type': 'home'}

# %%
type(data['phoneNumber'][0])
# Out:
# dict
